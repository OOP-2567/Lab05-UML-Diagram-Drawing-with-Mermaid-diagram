# %% [markdown]
# ## แบบฝึดหัด
#
# 1. ให้ค้นหา class diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
# 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
# 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

# %%
# %% Example 1.class diagram
# classDiagram
#     class MailSystem {
#         #Password
#         #Username
#         #Mail_Security()
#         #Check_DB()
#         #Inter_Mail_Comm()
#     }
#     class SendReceive {
#         #to
#         #cc
#         #sub
#         #msg
#         #attachment
#         #send_mail()
#         #receive_mail()
#         #compose_mail()
#     }
#     class Management {
#         #folder_name
#         #keyword
#         #create_folder()
#         #spam_filter()
#         #search()
#     }
#     class AudioVideo {
#         #tokens
#         #chat_msg
#         #speech_to_text()
#         #a_v_chat()
#         #a_v_dumps()
#     }
#     class Communication {
#         #time
#         #date
#         #RSS_Int()
#         #cross_chat()
#         #timed_del()
#     }
#     MailSystem <-- SendReceive
#     MailSystem <-- AudioVideo
#     Management <-- SendReceive
#     Management --> MailSystem
#     MailSystem <-- Communication
#     SendReceive <-- AudioVideo
#     SendReceive <-- Communication
#     AudioVideo -- Communication

# %% [markdown]
# 1.![image.png](attachment:image.png)

# %%
# %% Example 2.class diagram
# classDiagram
#         direction LR
#         class Staff {
#             -staffID: String
#             -staffName: String
#             -staffPosition: String
#             +staff()
#             +setter()
#             +getter()
#         }
#         class Feedback {
#             -complainDate: Date
#             -complainDesc: String
#             -feedback: String
#             +customerService()
#             +setFeedback()
#             +feedback()
#             +errorHandling()
#             +readFeedback()
#         }
#         direction LR
#         class User {
#             -userID: String
#             -email: String
#             -password: String
#             -userName: String
#             -listBudgetPlan: List<Budget>
#             +user()
#             +setter()
#             +getter()
#             +signup()
#             +login()
#             +totalBudget()
#             +makeTransaction()
#         }
#         class Budget {
#             -budget: Float
#             -precentage: Float
#             -label: String
#             -listTrans: List<ListTrans>
#             +budget()
#             +setter()
#             +getter()
#             +makeTransaction()
#             +makeSummary()
#         }
#     class ListTrans {
#         -transDate: Date
#         -transDesc: String
#         -transNominal: Float
#         +listTrans()
#         +setter()
#         +getter()
#     }
#     Staff "1..*" -- "0..*" Feedback
#     Feedback "0..*"--"1"User
#     User "1" -- "1..*" Budget
#     Budget "1" -- "1..*" ListTrans
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="73e595fcc620463d9dfbdc954120f4f1"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('73e595fcc620463d9dfbdc954120f4f1');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_73e595fcc620463d9dfbdc954120f4f1',
#                     `%% Example 2.class diagram
# classDiagram
#         direction LR
#         class Staff {
#             -staffID: String
#             -staffName: String
#             -staffPosition: String
#             +staff()
#             +setter()
#             +getter()
#         }
#         class Feedback {
#             -complainDate: Date
#             -complainDesc: String
#             -feedback: String
#             +customerService()
#             +setFeedback()
#             +feedback()
#             +errorHandling()
#             +readFeedback()
#         }
#         direction LR
#         class User {
#             -userID: String
#             -email: String
#             -password: String
#             -userName: String
#             -listBudgetPlan: List<Budget>
#             +user()
#             +setter()
#             +getter()
#             +signup()
#             +login()
#             +totalBudget()
#             +makeTransaction()
#         }
#         class Budget {
#             -budget: Float
#             -precentage: Float
#             -label: String
#             -listTrans: List<ListTrans>
#             +budget()
#             +setter()
#             +getter()
#             +makeTransaction()
#             +makeSummary()
#         }
#     class ListTrans {
#         -transDate: Date
#         -transDesc: String
#         -transNominal: Float
#         +listTrans()
#         +setter()
#         +getter()
#     }
#     Staff "1..*" -- "0..*" Feedback
#     Feedback "0..*"--"1"User
#     User "1" -- "1..*" Budget
#     Budget "1" -- "1..*" ListTrans `);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
#                 console.log(error);
#             }
# </script>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %% Example 3.class diagram
# classDiagram
#     class UserAdmin {
#         -Name: String
#         -Phone_numb: Integer
#         -EmailAddr: String
#         -Password: String
#         +Location(): void
#         +Search_market(): void
#         +Contact_Us(): void
#         +Update(): void
#     }
#     class MarketInformation {
#         -Market_name: String
#         -Address: String
#         -Location: String
#         -Opening_day: Date
#         -Opening_hour: String
#     }
#     class ContactUS {
#         -Name: String
#         -EmailAddr: String
#         -Phone_numb: Integer
#         -Message: String
#         +Send_Sms()
#         +Reply_Sms()
#     }
#     class Update {
#         -Name: String
#         -Phone_numb: Integer
#         -EmailAddr: String
#         -Password: String
#     }
#     class ViewLocation {
#         +Display_google_map()
#         +Show_location()
#     }
#
#     UserAdmin --> MarketInformation
#     UserAdmin --> ContactUS
#     UserAdmin --> Update
#     UserAdmin--> ViewLocation

# %% [markdown]
# 3.![image.png](attachment:image.png)
