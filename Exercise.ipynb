# %% [markdown]
# ## แบบฝึกหัด

# %%
flowchart LR
    A([Monitor doesn't 
    work])
    A ---> B{is monitor 
    plugged in?}
    B -- YES --> C{is monitor 
    burned out?}
    B -- NO --> D([Plug in monitor])
    C -- NO --> E{is HDMI cable
     plugged in?}
    C -- YES --> F([Replace monitor])
    E -- NO --> G([Plug in HDMI cable])
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="609f3ecd55aa46128e75b8c0ae518f98"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('609f3ecd55aa46128e75b8c0ae518f98');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_609f3ecd55aa46128e75b8c0ae518f98',
#                     `flowchart LR
#     A([Monitor doesn't
#     work])
#     A ---> B{is monitor
#     plugged in?}
#     B -- YES --> C{is monitor
#     burned out?}
#     B -- NO --> D([Plug in monitor])
#     C -- NO --> E{is HDMI cable
#      plugged in?}
#     C -- YES --> F([Replace monitor])
#     E -- NO --> G([Plug in HDMI cable])
#     `);
# ...

# %%
flowchart TD
    A([Lamp doesn't work]) --> B{Lamp plugged in?} -- Yes --> C{Bulb burned out?} -- No --> D([Repair lamp])
    B -- No --> E([Plug in lamp])
    C -- Yes --> F([Replace bulb])
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="8d57159958a849e5974d9e9375348626"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('8d57159958a849e5974d9e9375348626');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_8d57159958a849e5974d9e9375348626',
#                     `flowchart TD
#     A([Lamp doesn't work]) --> B{Lamp plugged in?} -- Yes --> C{Bulb burned out?} -- No --> D([Repair lamp])
#     B -- No --> E([Plug in lamp])
#     C -- Yes --> F([Replace bulb])`);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
# ...

# %%
flowchart LR
A([Start]) --> B[Step] --> C{Decision} -- Yes --> D[Action] --> E([End])
C -- No --> F[Action] --> G([End])
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="c2b63c8c2ec941fa95ce6cd137693722"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('c2b63c8c2ec941fa95ce6cd137693722');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_c2b63c8c2ec941fa95ce6cd137693722',
#                     `flowchart LR
# A([Start]) --> B[Step] --> C{Decision} -- Yes --> D[Action] --> E([End])
# C -- No --> F[Action] --> G([End])`);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
#                 console.log(error);
#             }
# </script>
# </div>

# %% [markdown]
# ## เปรียบเทียบจากที่วาด

# %% [markdown]
# ![image-2.png](attachment:image-2.png) ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)
