// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %%
sequenceDiagram
    Alice->>John: Hello John, how are you?
    John-->>Alice: Great!
    Alice-)John: See you later!
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="3861eb4ba6844c5caa2cd1c7a1bdb910"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('3861eb4ba6844c5caa2cd1c7a1bdb910');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_3861eb4ba6844c5caa2cd1c7a1bdb910',
//                     `sequenceDiagram
//     Alice->>John: Hello John, how are you?
//     John-->>Alice: Great!
//     Alice-)John: See you later!
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// > ```diff
// > sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM
// >```

// %%
sequenceDiagram
    User->>ATM: Insert card
    activate ATM
    ATM-->>User: Please input PIN
    deactivate ATM
    User->>ATM: Insert PIN
    activate ATM
    ATM-->>NetBank: Verify card and PIN
    activate NetBank
    NetBank-->>Bank: Verify account
    activate Bank
    Bank-->>NetBank: Invalid account
    deactivate Bank
    NetBank-->>ATM: Reject card
    deactivate NetBank
    ATM-->>User: Eject card
    deactivate ATM
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="f20afbe5284a49b190174d531cea38b1"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('f20afbe5284a49b190174d531cea38b1');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_f20afbe5284a49b190174d531cea38b1',
//                     `sequenceDiagram
//     User->>ATM: Insert card
//     activate ATM
//     ATM-->>User: Please input PIN
//     deactivate ATM
//     User->>ATM: Insert PIN
//     activate ATM
//     ATM-->>NetBank: Verify card and PIN
//     activate NetBank
//     NetBank-->>Bank: Verify account
//     activate Bank
//     Bank-->>NetBank: Invalid account
//     deactivate Bank
//     NetBank-->>ATM: Reject card
//     deactivate NetBank
//     ATM-->>User: Eject card
//     deactivate ATM`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// ภาพที่ 1

// %%
sequenceDiagram
    participant User
    participant System
    note left of System: Request with data
    note right of System: Response with result

    User->>System: search(keyword)
    activate System
    System->>System: processSearch(keyword)
    System->>User: found results
    deactivate System
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="e8bb748a2ece46ed91d7a65f180e9394"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('e8bb748a2ece46ed91d7a65f180e9394');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_e8bb748a2ece46ed91d7a65f180e9394',
//                     `sequenceDiagram
//     participant User
//     participant System
//     note left of System: Request with data
//     note right of System: Response with result
//
//     User->>System: search(keyword)
//     activate System
//     System->>System: processSearch(keyword)
//     System->>User: found results
//     deactivate System`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![22.png](attachment:22.png)

// %% [markdown]
// ภาพที่ 2

// %%
sequenceDiagram
    participant User
    participant "Login Page"
    participant "Database" as DB
    participant "Main Page"
    participant "Login Failure Page"

    User->>"Login Page": Visit
    activate "Login Page"
    User->>"Login Page": Enter Login Info
    "Login Page"->> DB: Verify credentials
    activate DB
    DB->> "Login Page": Authentication result
    deactivate DB
    alt Authentication successful
        "Login Page"->> "Main Page": Redirect
    else Authentication failed
        "Login Page"->> "Login Failure Page": Redirect
    end
    deactivate "Login Page"
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="58ea12d380384989a48f01d389941de1"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('58ea12d380384989a48f01d389941de1');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_58ea12d380384989a48f01d389941de1',
//                     `sequenceDiagram
//     participant User
//     participant "Login Page"
//     participant "Database" as DB
//     participant "Main Page"
//     participant "Login Failure Page"
//
//     User->>"Login Page": Visit
//     activate "Login Page"
//     User->>"Login Page": Enter Login Info
//     "Login Page"->> DB: Verify credentials
//     activate DB
//     DB->> "Login Page": Authentication result
//     deactivate DB
//     alt Authentication successful
//         "Login Page"->> "Main Page": Redirect
//     else Authentication failed
//         "Login Page"->> "Login Failure Page": Redirect
//     end
//     deactivate "Login Page"`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![33.png](attachment:33.png)

// %% [markdown]
// ภาพที่ 3

// %%
sequenceDiagram
    participant Student
    participant Catalog
    participant Book
    participant Loan

    Student->>Catalog: searchByAuthor()
    activate Catalog
    Catalog-->>Student: printResults()
    deactivate Catalog

    Student->>Catalog: searchByAuthor()
    activate Catalog
    Catalog-->>Book: isAvailable(bookID)
    activate Book
    Book-->>Catalog: newSearch()
    deactivate Book
    Catalog->>Student: newSearch()
    deactivate Catalog

    Student->>Catalog: searchByAuthor()
    activate Catalog
    Catalog-->>Book: isAvailable(bookID)
    activate Book
    Book-->>Loan: checkOut()
    activate Loan
    Loan-->>Loan: checkFines()
    Loan-->>Catalog: updateCatalog()
    Catalog-->>Student: printReceipt()
    Loan-->>Student: payFines()
    Loan-->>Student: createLy
    deactivate Loan
    deactivate Book
    deactivate Catalog
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="9a83d1613c83409b8ca0f8841b655696"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('9a83d1613c83409b8ca0f8841b655696');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_9a83d1613c83409b8ca0f8841b655696',
//                     `sequenceDiagram
//     participant Student
//     participant Catalog
//     participant Book
//     participant Loan
//
//     Student->>Catalog: searchByAuthor()
//     activate Catalog
//     Catalog-->>Student: printResults()
//     deactivate Catalog
//
//     Student->>Catalog: searchByAuthor()
//     activate Catalog
//     Catalog-->>Book: isAvailable(bookID)
//     activate Book
//     Book-->>Catalog: newSearch()
//     deactivate Book
//     Catalog->>Student: newSearch()
//     deactivate Catalog
//
//     Student->>Catalog: searchByAuthor()
//     activate Catalog
//     Catalog-->>Book: isAvailable(bookID)
//     activate Book
//     Book-->>Loan: checkOut()
//     activate Loan
//     Loan-->>Loan: checkFines()
//     Loan-->>Catalog: updateCatalog()
//     Catalog-->>Student: printReceipt()
//     Loan-->>Student: payFines()
//     Loan-->>Student: createLy
//     deactivate Loan
//     deactivate Book
//     deactivate Catalog`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![1.png](attachment:1.png)
