// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %%
sequenceDiagram
    Alice->>John: Hello John, how are you?
    John-->>Alice: Great!
    Alice-)John: See you later!

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// > ```diff
// > sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM
// >```

// %%
sequenceDiagram
    User->>ATM: Insert card
    activate ATM
    ATM-->>User: Please input PIN
    deactivate ATM
    User->>ATM: Insert PIN
    activate ATM
    ATM-->>NetBank: Verify card and PIN
    activate NetBank
    NetBank-->>Bank: Verify account
    activate Bank
    Bank-->>NetBank: Invalid account
    deactivate Bank
    NetBank-->>ATM: Reject card
    deactivate NetBank
    ATM-->>User: Eject card
    deactivate ATM

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// 1.1 https://blogfiles.miocreate.com/image/20230608/112350-sequence-diagram-example-1.jpeg
//
// 1.2 https://i.pinimg.com/originals/2b/42/ba/2b42ba93f0750ff4cd981afd1f76bea8.png
//
// 1.3 https://i.pinimg.com/originals/57/c4/d7/57c4d70b98744e14aa25f024433a0299.png

// %% [markdown]
// ## ข้อ2.1 ทำตามรูป 1.1

// %%
sequenceDiagram
    participant Customer
    participant AppInterface as Application Interface
    participant ItemId as Item ID
    participant Purchase as Purchase Interface
    participant Checkout
    participant NormalOrder as Normal Order

    Customer->>AppInterface: browse item
    AppInterface->>ItemId: query item
    ItemId-->>AppInterface: get selected item
    Customer->>AppInterface: select item
    AppInterface->>Purchase: purchase
    Purchase->>ItemId: get selected item
    ItemId-->>Purchase: get selected item
    Purchase->>Checkout: authorize purchase
    Checkout->>NormalOrder: authorization
    NormalOrder-->>Checkout: authorization
    Checkout-->>Purchase: authorize purchase
    Purchase-->>AppInterface: display selected item
    AppInterface-->>Customer: display price info

// %% [markdown]
// ## ข้อ2.2 ทำตามรูป 1.2

// %%
sequenceDiagram
    participant Student
    participant Website as Web Site
    participant WebServer as Web Server
    participant Admin
    participant DB

    Student->>Website: Click on register tab()
    Website->>WebServer: Request register page()
    WebServer-->>Website: Return register page()
    Website-->>Student: Display Register field()
    Student->>Website: Enter information()
    Student->>Website: Click submit button()
    Website->>WebServer: Send new student information()
    WebServer->>Admin: Verify new student information()
    Admin-->>WebServer: Invalid new student()
    WebServer-->>Website: Send errors()
    Website-->>Student: ReEnter information()
    Student->>Website: ReEnter information()
    Website->>WebServer: Send new student information()
    WebServer->>Admin: Verify new student information()
    Admin-->>WebServer: Valid new student()
    WebServer->>DB: Save()
    WebServer-->>Website: Send acceptance email()
    Website-->>Student: Send acceptance email()

// %% [markdown]
// ## ข้อ2.3 ทำตามรูป 1.3

// %%
sequenceDiagram
    actor Student
    Student ->> Login Screen: click on login button
    Login Screen ->> Validate User: ValidateUser(userid, password)
    Validate User ->> Database: userID:found.password:matched
    Database -->> Validate User: classList(grades)
    Validate User -->> Login Screen: User login successful
    Login Screen -->> Student: loginSuccessful:message
    Login Screen -->> Student: display:classList(grades)
    
    Database -->> Validate User: ValidateUser(passwordMatched)
    Note left of Login Screen: text

// %% [markdown]
// ### 3.1 เปรียบเทียบผลข้อ 1.1 กับ 2.1
// 1. [Mermaid sequenceDiagram ]
//
// ![00987.png](attachment:00987.png) ![236.png](attachment:236.png)
//
// 2. [ sequenceDiagram ]
//
// ![6547.png](attachment:6547.png)

// %% [markdown]
// ### 3.2 เปรียบเทียบผลข้อ 1.2 กับ 2.2
// 1. [Mermaid sequenceDiagram ]
//
// ![00988.png](attachment:00988.png)![00989.png](attachment:00989.png)
//
// 2. [ sequenceDiagram ]
//
// ![9999.png](attachment:9999.png)

// %% [markdown]
// ### 3.3 เปรียบเทียบผลข้อ 1.3 กับ 2.3
// 1. [Mermaid sequenceDiagram ]
//
// ![00990.png](attachment:00990.png)
//
// 2. [ sequenceDiagram ]
//
// ![0299.png](attachment:0299.png)
