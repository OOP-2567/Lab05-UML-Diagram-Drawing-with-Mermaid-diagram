// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %%
sequenceDiagram
    Alice->>John: Hello John, how are you?
    John-->>Alice: Great!
    Alice-)John: See you later!
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="58684243306a4ad996c89157cfef4414"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('58684243306a4ad996c89157cfef4414');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_58684243306a4ad996c89157cfef4414',
//                     `sequenceDiagram
//     Alice->>John: Hello John, how are you?
//     John-->>Alice: Great!
//     Alice-)John: See you later!`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// > ```diff
// > sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM
// >```

// %%
sequenceDiagram
    User->>ATM: Insert card
    activate ATM
    ATM-->>User: Please input PIN
    deactivate ATM
    User->>ATM: Insert PIN
    activate ATM
    ATM-->>NetBank: Verify card and PIN
    activate NetBank
    NetBank-->>Bank: Verify account
    activate Bank
    Bank-->>NetBank: Invalid account
    deactivate Bank
    NetBank-->>ATM: Reject card
    deactivate NetBank
    ATM-->>User: Eject card
    deactivate ATM
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="1355b2bf3b2a46368240d84324cd17ca"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('1355b2bf3b2a46368240d84324cd17ca');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_1355b2bf3b2a46368240d84324cd17ca',
//                     `sequenceDiagram
//     User->>ATM: Insert card
//     activate ATM
//     ATM-->>User: Please input PIN
//     deactivate ATM
//     User->>ATM: Insert PIN
//     activate ATM
//     ATM-->>NetBank: Verify card and PIN
//     activate NetBank
//     NetBank-->>Bank: Verify account
//     activate Bank
//     Bank-->>NetBank: Invalid account
//     deactivate Bank
//     NetBank-->>ATM: Reject card
//     deactivate NetBank
//     ATM-->>User: Eject card
//     deactivate ATM
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
//
// 1.1
//
// ![image.png](attachment:image.png)
//
//
// 1.2
//
//
// ![image-3.png](attachment:image-3.png)
//
//
// 1.3
//
// ![image-2.png](attachment:image-2.png)

// %% [markdown]
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น

// %%
sequenceDiagram
    participant Customer
    participant LoginUI
    participant LoginControl
    participant UserDB

    Customer->>LoginUI: Logging(Un/Pw)
    activate LoginUI
    LoginUI->>LoginControl: login(Un/Pw)
    activate LoginControl
    LoginControl->>UserDB: search(Un/Pw)
    activate UserDB
    UserDB-->>LoginControl: status
    activate LoginControl
    LoginControl->>LoginControl: validateUser
    LoginControl-->>LoginUI: status
    deactivate LoginControl
    deactivate UserDB
    LoginUI-->>Customer: status
    deactivate LoginUI
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="f83576b870264b90b749e58fe1ccf341"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('f83576b870264b90b749e58fe1ccf341');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_f83576b870264b90b749e58fe1ccf341',
//                     `sequenceDiagram
//     participant Customer
//     participant LoginUI
//     participant LoginControl
//     participant UserDB
//
//     Customer->>LoginUI: Logging(Un/Pw)
//     activate LoginUI
//     LoginUI->>LoginControl: login(Un/Pw)
//     activate LoginControl
//     LoginControl->>UserDB: search(Un/Pw)
//     activate UserDB
//     UserDB-->>LoginControl: status
//     activate LoginControl
//     LoginControl->>LoginControl: validateUser
//     LoginControl-->>LoginUI: status
//     deactivate LoginControl
//     deactivate UserDB
//     LoginUI-->>Customer: status
//     deactivate LoginUI`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
sequenceDiagram
    participant Student
    participant LoginScreen
    participant ValidateUser
    participant Database

    Student ->> LoginScreen: click on login button
    LoginScreen ->> ValidateUser: Validate(user, password)
    ValidateUser ->> Database: userID found\npassword matched
    Database -->> ValidateUser: classList(grades)
    ValidateUser -->> LoginScreen: User login successful
    LoginScreen -->> Student: loginSuccessful.message
    Student ->> LoginScreen: display(classList(grades))
    alt class == null
        LoginScreen ->> Student: Access denied
    end
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="50fd9a21e82a4a75b71c2da6836bc41a"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('50fd9a21e82a4a75b71c2da6836bc41a');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_50fd9a21e82a4a75b71c2da6836bc41a',
//                     `sequenceDiagram
//     participant Student
//     participant LoginScreen
//     participant ValidateUser
//     participant Database
//
//     Student ->> LoginScreen: click on login button
//     LoginScreen ->> ValidateUser: Validate(user, password)
//     ValidateUser ->> Database: userID found\\npassword matched
//     Database -->> ValidateUser: classList(grades)
//     ValidateUser -->> LoginScreen: User login successful
//     LoginScreen -->> Student: loginSuccessful.message
//     Student ->> LoginScreen: display(classList(grades))
//     alt class == null
//         LoginScreen ->> Student: Access denied
//     end
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
sequenceDiagram
    participant Customer
    participant SearchForm
    participant SearchResults
    participant ItemDatabase
    participant ResultList

    Customer ->> SearchForm: itemSearch(itemName)
    SearchForm ->> SearchForm: validSearch()
    alt itemName == valid
        SearchForm ->> SearchResults: SearchItems(itemName)
        SearchResults ->> ItemDatabase: listResults()
        ItemDatabase -->> SearchResults: displayResults()
        SearchResults -->> ResultList: displayResults()
    else
        SearchForm ->> Customer: displayError()
    end
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="3b33bd36e0ac43b3ae05fd8cea4a0244"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('3b33bd36e0ac43b3ae05fd8cea4a0244');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_3b33bd36e0ac43b3ae05fd8cea4a0244',
//                     `sequenceDiagram
//     participant Customer
//     participant SearchForm
//     participant SearchResults
//     participant ItemDatabase
//     participant ResultList
//
//     Customer ->> SearchForm: itemSearch(itemName)
//     SearchForm ->> SearchForm: validSearch()
//     alt itemName == valid
//         SearchForm ->> SearchResults: SearchItems(itemName)
//         SearchResults ->> ItemDatabase: listResults()
//         ItemDatabase -->> SearchResults: displayResults()
//         SearchResults -->> ResultList: displayResults()
//     else
//         SearchForm ->> Customer: displayError()
//     end
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)
//
// 3.1
//
// ![image.png](attachment:image.png)
//
// 3.2
//
// ![image-2.png](attachment:image-2.png)
//
// 3.3
//
// ![image-3.png](attachment:image-3.png)
