// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %%
sequenceDiagram
    Alice->>John: Hello John, how are you?
    John-->>Alice: Great!
    Alice-)John: See you later!
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="a16ed1037574499cb5b8123bb97178d7"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('a16ed1037574499cb5b8123bb97178d7');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_a16ed1037574499cb5b8123bb97178d7',
//                     `sequenceDiagram
//     Alice->>John: Hello John, how are you?
//     John-->>Alice: Great!
//     Alice-)John: See you later!`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// > ```diff
// > sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM
// >```

// %%
sequenceDiagram
    User->>ATM: Insert card
    activate ATM
    ATM-->>User: Please input PIN
    deactivate ATM
    User->>ATM: Insert PIN
    activate ATM
    ATM-->>NetBank: Verify card and PIN
    activate NetBank
    NetBank-->>Bank: Verify account
    activate Bank
    Bank-->>NetBank: Invalid account
    deactivate Bank
    NetBank-->>ATM: Reject card
    deactivate NetBank
    ATM-->>User: Eject card
    deactivate ATM
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="98c68d2b7d5e4933a1f5767de10e2c36"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('98c68d2b7d5e4933a1f5767de10e2c36');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_98c68d2b7d5e4933a1f5767de10e2c36',
//                     `
// sequenceDiagram
//     User->>ATM: Insert card
//     activate ATM
//     ATM-->>User: Please input PIN
//     deactivate ATM
//     User->>ATM: Insert PIN
//     activate ATM
//     ATM-->>NetBank: Verify card and PIN
//     activate NetBank
//     NetBank-->>Bank: Verify account
//     activate Bank
//     Bank-->>NetBank: Invalid account
//     deactivate Bank
//     NetBank-->>ATM: Reject card
//     deactivate NetBank
//     ATM-->>User: Eject card
//     deactivate ATM`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// ภาพที่ 1

// %% [markdown]
// ![05.03.1.png](attachment:05.03.1.png)

// %% [markdown]
// ภาพที่ 2

// %% [markdown]
// ![05.03.2.png](attachment:05.03.2.png)

// %% [markdown]
// ภาพที่ 3

// %% [markdown]
// ![05.03.3.png](attachment:05.03.3.png)

// %% [markdown]
// เขียน code ภาษา mermaid (ภาพที่1)

// %%
sequenceDiagram
    participant User
    participant System
    participant Database

    User->>System: Login information
    System->>Database: Compare login details
    Database-->>System: Return results

    alt If login ID and password match
        System->>User: Confirm login
    else
        System->>User: Reject login
    end
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="2772a5a23f0d473aad0ef7b1a8ad39de"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('2772a5a23f0d473aad0ef7b1a8ad39de');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_2772a5a23f0d473aad0ef7b1a8ad39de',
//                     `sequenceDiagram
//     participant User
//     participant System
//     participant Database
//
//     User->>System: Login information
//     System->>Database: Compare login details
//     Database-->>System: Return results
//
//     alt If login ID and password match
//         System->>User: Confirm login
//     else
//         System->>User: Reject login
//     end`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// เขียน code ภาษา mermaid (ภาพที่2)

// %%
sequenceDiagram
    participant Customer
    participant APP
    participant AuthServer as Auth Server
    participant BankServer as Bank Server

    Customer->>APP: Login
    APP->>AuthServer: verify password
    alt if password is valid
        AuthServer-->>APP: return JWT
        APP-->>Customer: return OK
    else
        AuthServer-->>APP: return Invalid
        APP-->>Customer: return Invalid
    end
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="aefd6c34221f492c868cbe493684051d"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('aefd6c34221f492c868cbe493684051d');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_aefd6c34221f492c868cbe493684051d',
//                     `sequenceDiagram
//     participant Customer
//     participant APP
//     participant AuthServer as Auth Server
//     participant BankServer as Bank Server
//
//     Customer->>APP: Login
//     APP->>AuthServer: verify password
//     alt if password is valid
//         AuthServer-->>APP: return JWT
//         APP-->>Customer: return OK
//     else
//         AuthServer-->>APP: return Invalid
//         APP-->>Customer: return Invalid
//     end`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// เขียน code ภาษา mermaid (ภาพที่3)

// %%
sequenceDiagram
    participant Customer
    participant SearchForm
    participant SearchResults
    participant ItemDatabase
    participant ResultList

    Customer->>SearchForm: itemSearch(itemName)
    SearchForm->>SearchForm: validSearch()

    alt [itemName=valid]
        SearchForm->>SearchResults: SearchItems(itemName)
        SearchResults->>ItemDatabase: listResults()
        ItemDatabase-->>SearchResults: displayResults()
    else [else]
        SearchForm->>SearchForm: displayError()
    end
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="960fc70ef26c4a2595f480912162d593"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('960fc70ef26c4a2595f480912162d593');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_960fc70ef26c4a2595f480912162d593',
//                     `sequenceDiagram
//     participant Customer
//     participant SearchForm
//     participant SearchResults
//     participant ItemDatabase
//     participant ResultList
//
//     Customer->>SearchForm: itemSearch(itemName)
//     SearchForm->>SearchForm: validSearch()
//
//     alt [itemName=valid]
//         SearchForm->>SearchResults: SearchItems(itemName)
//         SearchResults->>ItemDatabase: listResults()
//         ItemDatabase-->>SearchResults: displayResults()
//     else [else]
//         SearchForm->>SearchForm: displayError()
//     end`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// เปรียบเทียบภาพที่ 1

// %% [markdown]
// ![05.03.1.1.png](attachment:05.03.1.1.png)

// %% [markdown]
// เปรียบเทียบภาพที่ 2

// %% [markdown]
// ![05.03.2.2.png](attachment:05.03.2.2.png)

// %% [markdown]
// เปรียบเทียบภาพที่ 3

// %% [markdown]
// ![05.03.3.3.png](attachment:05.03.3.3.png)
