// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %%
sequenceDiagram
Alice->>John: Hello John, how are you?
John-->>Alice: Great!
Alice-)John: See you later!
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="810ae469ba7e4c1a9bb612642a60f7bb"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('810ae469ba7e4c1a9bb612642a60f7bb');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_810ae469ba7e4c1a9bb612642a60f7bb',
//                     `sequenceDiagram
// Alice->>John: Hello John, how are you?
// John-->>Alice: Great!
// Alice-)John: See you later!`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// > ```diff
// > sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM
// >```

// %%
sequenceDiagram
User->>ATM: Insert card
activate ATM
ATM-->>User: Please input PIN
deactivate ATM
User->>ATM: Insert PIN
activate ATM
ATM-->>NetBank: Verify card and PIN
activate NetBank
NetBank-->>Bank: Verify account
activate Bank
Bank-->>NetBank: Invalid account
deactivate Bank
NetBank-->>ATM: Reject card
deactivate NetBank
ATM-->>User: Eject card
deactivate ATM
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="e00809afec884d89be2d6e54fa447e62"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('e00809afec884d89be2d6e54fa447e62');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_e00809afec884d89be2d6e54fa447e62',
//                     `
// sequenceDiagram
// User->>ATM: Insert card
// activate ATM
// ATM-->>User: Please input PIN
// deactivate ATM
// User->>ATM: Insert PIN
// activate ATM
// ATM-->>NetBank: Verify card and PIN
// activate NetBank
// NetBank-->>Bank: Verify account
// activate Bank
// Bank-->>NetBank: Invalid account
// deactivate Bank
// NetBank-->>ATM: Reject card
// deactivate NetBank
// ATM-->>User: Eject card
// deactivate ATM`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %%
sequenceDiagram
    participant User
    participant WebPage
    participant Server

    User->>WebPage: กรอกชื่อผู้ใช้และรหัสผ่าน
    WebPage->>Server: ส่งข้อมูลสำหรับการตรวจสอบ
    Server->>WebPage: ส่งผลลัพธ์การตรวจสอบ
    WebPage->>User: แสดงผลลัพธ์การเข้าสู่ระบบ
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="742e55269a4e4bbc884e5df246a68a9c"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('742e55269a4e4bbc884e5df246a68a9c');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_742e55269a4e4bbc884e5df246a68a9c',
//                     `sequenceDiagram
//     participant User
//     participant WebPage
//     participant Server
//
//     User->>WebPage: กรอกชื่อผู้ใช้และรหัสผ่าน
//     WebPage->>Server: ส่งข้อมูลสำหรับการตรวจสอบ
//     Server->>WebPage: ส่งผลลัพธ์การตรวจสอบ
//     WebPage->>User: แสดงผลลัพธ์การเข้าสู่ระบบ
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
sequenceDiagram
    participant User
    participant WebPage
    participant PaymentSystem
    participant Server
    participant DeliveryService

    User->>WebPage: เลือกสินค้าและเพิ่มลงในตะกร้า
    User->>WebPage: ดำเนินการชำระเงิน
    WebPage->>PaymentSystem: ส่งข้อมูลการชำระเงิน
    PaymentSystem->>Server: ยืนยันการชำระเงิน
    Server->>DeliveryService: ส่งข้อมูลการสั่งซื้อ
    DeliveryService->>User: จัดส่งสินค้า
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="c72ee003fc624554aa0c1035d29e51c1"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('c72ee003fc624554aa0c1035d29e51c1');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_c72ee003fc624554aa0c1035d29e51c1',
//                     `sequenceDiagram
//     participant User
//     participant WebPage
//     participant PaymentSystem
//     participant Server
//     participant DeliveryService
//
//     User->>WebPage: เลือกสินค้าและเพิ่มลงในตะกร้า
//     User->>WebPage: ดำเนินการชำระเงิน
//     WebPage->>PaymentSystem: ส่งข้อมูลการชำระเงิน
//     PaymentSystem->>Server: ยืนยันการชำระเงิน
//     Server->>DeliveryService: ส่งข้อมูลการสั่งซื้อ
//     DeliveryService->>User: จัดส่งสินค้า
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
sequenceDiagram
    participant User
    participant App
    participant Server
    participant Theater

    User->>App: เลือกภาพยนตร์และเวลา
    App->>User: แสดงรายละเอียดและราคาตั๋ว
    User->>App: ยืนยันการจองและชำระเงิน
    App->>Server: ส่งข้อมูลการชำระเงิน
    Server->>Theater: ส่งข้อมูลการจอง
    Theater->>User: แสดงตั๋วและที่นั่ง
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="c7235a03e1184ffbbcd80f728a5823f0"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('c7235a03e1184ffbbcd80f728a5823f0');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_c7235a03e1184ffbbcd80f728a5823f0',
//                     `sequenceDiagram
//     participant User
//     participant App
//     participant Server
//     participant Theater
//
//     User->>App: เลือกภาพยนตร์และเวลา
//     App->>User: แสดงรายละเอียดและราคาตั๋ว
//     User->>App: ยืนยันการจองและชำระเงิน
//     App->>Server: ส่งข้อมูลการชำระเงิน
//     Server->>Theater: ส่งข้อมูลการจอง
//     Theater->>User: แสดงตั๋วและที่นั่ง
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)
