// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %%
sequenceDiagram
   Alice->>John: Hello John, how are you?
   John-->>Alice: Great!
   Alice-)John: See you later!
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="c76f84be13be4865a6f174c75813d4b7"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('c76f84be13be4865a6f174c75813d4b7');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_c76f84be13be4865a6f174c75813d4b7',
//                     `sequenceDiagram
//    Alice->>John: Hello John, how are you?
//    John-->>Alice: Great!
//    Alice-)John: See you later!`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// > ```diff
// > sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM
// >```

// %%
sequenceDiagram
   User->>ATM: Insert card
   activate ATM
   ATM-->>User: Please input PIN
   deactivate ATM
   User->>ATM: Insert PIN
   activate ATM
   ATM-->>NetBank: Verify card and PIN
   activate NetBank
   NetBank-->>Bank: Verify account
   activate Bank
   Bank-->>NetBank: Invalid account
   deactivate Bank
   NetBank-->>ATM: Reject card
   deactivate NetBank
   ATM-->>User: Eject card
   deactivate ATM
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="88a8d8c3689d4417b57e6fac231f348b"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('88a8d8c3689d4417b57e6fac231f348b');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_88a8d8c3689d4417b57e6fac231f348b',
//                     `
// sequenceDiagram
//    User->>ATM: Insert card
//    activate ATM
//    ATM-->>User: Please input PIN
//    deactivate ATM
//    User->>ATM: Insert PIN
//    activate ATM
//    ATM-->>NetBank: Verify card and PIN
//    activate NetBank
//    NetBank-->>Bank: Verify account
//    activate Bank
//    Bank-->>NetBank: Invalid account
//    deactivate Bank
//    NetBank-->>ATM: Reject card
//    deactivate NetBank
//    ATM-->>User: Eject card
//    deactivate ATM`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png) ที่หามา

// %%
sequenceDiagram
    participant User
    participant Device
    participant System
    
    User->>Device: Open Application
    Device->>User: 
    User->>Device: Access Webcam
    Device->>User: 
    User->>Device: Get Photo
    Device->>User: Photo
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="5deadae845404a4cacc6f7f53dfb07e4"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('5deadae845404a4cacc6f7f53dfb07e4');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_5deadae845404a4cacc6f7f53dfb07e4',
//                     `sequenceDiagram
//     participant User
//     participant Device
//     participant System
//
//     User->>Device: Open Application
//     Device->>User:
//     User->>Device: Access Webcam
//     Device->>User:
//     User->>Device: Get Photo
//     Device->>User: Photo`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
sequenceDiagram
    participant User
    participant System
    
    opt loginSuccess == true
        User->>System: 
        System->>User: Display welcome message
    end
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="ffdaa355ef9941aeb9ba91092c4f8d7d"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('ffdaa355ef9941aeb9ba91092c4f8d7d');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_ffdaa355ef9941aeb9ba91092c4f8d7d',
//                     `sequenceDiagram
//     participant User
//     participant System
//
//     opt loginSuccess == true
//         User->>System:
//         System->>User: Display welcome message
//     end`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
sequenceDiagram
    participant StoreFront
    participant Cart
    participant Inventory
    
    loop
        StoreFront->>Cart: AddItem
        Cart->>Inventory: ReserveItem
    end
    StoreFront->>Cart: Checkout
    Cart->>StoreFront: ConfirmOrder
    StoreFront->>Inventory: ProcessOrder
    Inventory->>StoreFront: PlaceIteminOrder
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="5c186f41d3bf4765adc4a9cdfc0aca5f"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('5c186f41d3bf4765adc4a9cdfc0aca5f');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_5c186f41d3bf4765adc4a9cdfc0aca5f',
//                     `sequenceDiagram
//     participant StoreFront
//     participant Cart
//     participant Inventory
//
//     loop
//         StoreFront->>Cart: AddItem
//         Cart->>Inventory: ReserveItem
//     end
//     StoreFront->>Cart: Checkout
//     Cart->>StoreFront: ConfirmOrder
//     StoreFront->>Inventory: ProcessOrder
//     Inventory->>StoreFront: PlaceIteminOrder`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>
