// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
//
// >sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM

// %%
sequenceDiagram
    Alice->>John: Hello John, how are you?
    John-->>Alice: Great!
    Alice-)John: See you later!
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="1e092d7030e641ecb55cd58fe2ba1f30"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('1e092d7030e641ecb55cd58fe2ba1f30');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_1e092d7030e641ecb55cd58fe2ba1f30',
//                     `sequenceDiagram
//     Alice->>John: Hello John, how are you?
//     John-->>Alice: Great!
//     Alice-)John: See you later!
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// 1.ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
//
// ![image.png](attachment:image.png)
//
// ![image-2.png](attachment:image-2.png)
//
// ![image-3.png](attachment:image-3.png)

// %% [markdown]
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น

// %%
sequenceDiagram
    participant ผู้ใช้เครื่อง as ผู้ใช้เครื่อง
    participant เครื่องATM as เครื่อง ATM
    participant ปุ่มหมายเลข as ปุ่มหมายเลข
    participant หน้าจอ as หน้าจอ
    participant บัญชีเงินฝาก as บัญชีเงินฝาก
    participant เครื่องจ่ายเงิน as เครื่องจ่ายเงิน
    participant เครื่องพิมพ์ as เครื่องพิมพ์

    ผู้ใช้เครื่อง->>เครื่องATM: สอดบัตร
    เครื่องATM->>ปุ่มหมายเลข: กด (รหัส)
    alt รหัสไม่ถูกต้อง
        หน้าจอ-->>ผู้ใช้เครื่อง: แสดงข้อความแจ้งเตือน
    else รหัสถูกต้อง
        หน้าจอ-->>ผู้ใช้เครื่อง: แสดง Main Menu
        ผู้ใช้เครื่อง->>ปุ่มหมายเลข: กด (จำนวนเงิน)
        เครื่องATM->>บัญชีเงินฝาก: ตรวจสอบยอดคงเหลือ
        alt ยอดเงินเพียงพอ
            บัญชีเงินฝาก-->>เครื่องATM: ยอดเงินคงเหลือ
            เครื่องATM->>เครื่องจ่ายเงิน: จ่ายเงิน (จำนวนเงิน)
            เครื่องATM->>เครื่องพิมพ์: พิมพ์ SLIP
        else ยอดเงินไม่เพียงพอ
            หน้าจอ-->>ผู้ใช้เครื่อง: แสดงข้อความแจ้งเตือน
        end
    end
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="28a47ea8681f43cdb5241d06f332b7b0"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('28a47ea8681f43cdb5241d06f332b7b0');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_28a47ea8681f43cdb5241d06f332b7b0',
//                     `sequenceDiagram
//     participant ผู้ใช้เครื่อง as ผู้ใช้เครื่อง
//     participant เครื่องATM as เครื่อง ATM
//     participant ปุ่มหมายเลข as ปุ่มหมายเลข
//     participant หน้าจอ as หน้าจอ
//     participant บัญชีเงินฝาก as บัญชีเงินฝาก
//     participant เครื่องจ่ายเงิน as เครื่องจ่ายเงิน
//     participant เครื่องพิมพ์ as เครื่องพิมพ์
//
//     ผู้ใช้เครื่อง->>เครื่องATM: สอดบัตร
//     เครื่องATM->>ปุ่มหมายเลข: กด (รหัส)
//     alt รหัสไม่ถูกต้อง
//         หน้าจอ-->>ผู้ใช้เครื่อง: แสดงข้อความแจ้งเตือน
//     else รหัสถูกต้อง
//         หน้าจอ-->>ผู้ใช้เครื่อง: แสดง Main Menu
//         ผู้ใช้เครื่อง->>ปุ่มหมายเลข: กด (จำนวนเงิน)
//         เครื่องATM->>บัญชีเงินฝาก: ตรวจสอบยอดคงเหลือ
//         alt ยอดเงินเพียงพอ
//             บัญชีเงินฝาก-->>เครื่องATM: ยอดเงินคงเหลือ
//             เครื่องATM->>เครื่องจ่ายเงิน: จ่ายเงิน (จำนวนเงิน)
//             เครื่องATM->>เครื่องพิมพ์: พิมพ์ SLIP
//         else ยอดเงินไม่เพียงพอ
//             หน้าจอ-->>ผู้ใช้เครื่อง: แสดงข้อความแจ้งเตือน
//         end
//     end
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
sequenceDiagram
    participant aClient
    participant DreamHomeController
    participant PropertyForRent
    participant Lease
    participant Viewing

    aClient->>DreamHomeController: SearchProperties()
    activate DreamHomeController
    DreamHomeController->>PropertyForRent: matchPreferences(prefType, maxRent)
    activate PropertyForRent
    PropertyForRent->>Lease: checkAvailability(pfrNo)
    activate Lease
    Lease-->>PropertyForRent: returnAvailability()
    deactivate Lease
    PropertyForRent-->>DreamHomeController: returnPFRAvailability()
    deactivate PropertyForRent
    DreamHomeController-->>aClient: returnResults()
    aClient->>DreamHomeController: arrangeViewing()
    DreamHomeController->>Viewing: arrangeView(aClientNo, pfrNo, viewDate)
    activate Viewing
    deactivate Viewing
    deactivate DreamHomeController
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="2f78d65ee68b44259de6ac8aa62daef7"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('2f78d65ee68b44259de6ac8aa62daef7');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_2f78d65ee68b44259de6ac8aa62daef7',
//                     `sequenceDiagram
//     participant aClient
//     participant DreamHomeController
//     participant PropertyForRent
//     participant Lease
//     participant Viewing
//
//     aClient->>DreamHomeController: SearchProperties()
//     activate DreamHomeController
//     DreamHomeController->>PropertyForRent: matchPreferences(prefType, maxRent)
//     activate PropertyForRent
//     PropertyForRent->>Lease: checkAvailability(pfrNo)
//     activate Lease
//     Lease-->>PropertyForRent: returnAvailability()
//     deactivate Lease
//     PropertyForRent-->>DreamHomeController: returnPFRAvailability()
//     deactivate PropertyForRent
//     DreamHomeController-->>aClient: returnResults()
//     aClient->>DreamHomeController: arrangeViewing()
//     DreamHomeController->>Viewing: arrangeView(aClientNo, pfrNo, viewDate)
//     activate Viewing
//     deactivate Viewing
//     deactivate DreamHomeController`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %%
sequenceDiagram
    participant cust as Customer
    participant teller as ATM
    participant theirBank as Bank

    cust->>teller: withdrawCash(accNum, amount)
    teller->>theirBank: getBalance(accNum)
    activate theirBank
    theirBank-->>teller: balance
    deactivate theirBank
    
    alt balance > amount
        teller->>theirBank: debit(accNum, amount)
        activate theirBank
        theirBank-->>teller: success
        deactivate theirBank
        teller-->>cust: cash
    else
        teller-->>cust: insufficient funds
    end
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="73a069d669884811a43f6fd22d92245e"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('73a069d669884811a43f6fd22d92245e');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_73a069d669884811a43f6fd22d92245e',
//                     `sequenceDiagram
//     participant cust as Customer
//     participant teller as ATM
//     participant theirBank as Bank
//
//     cust->>teller: withdrawCash(accNum, amount)
//     teller->>theirBank: getBalance(accNum)
//     activate theirBank
//     theirBank-->>teller: balance
//     deactivate theirBank
//
//     alt balance > amount
//         teller->>theirBank: debit(accNum, amount)
//         activate theirBank
//         theirBank-->>teller: success
//         deactivate theirBank
//         teller-->>cust: cash
//     else
//         teller-->>cust: insufficient funds
//     end
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)
//
// ![image.png](attachment:image.png)
//
// ![image-3.png](attachment:image-3.png)
//
// ![image-2.png](attachment:image-2.png)
