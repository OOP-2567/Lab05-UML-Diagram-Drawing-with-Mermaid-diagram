// %% [markdown]
// # Lab 5.3 การวาด sequence diagram ด้วย mermaid diagram

// %% [markdown]
// ### 5.3.1 องค์ประกอบของ sequence diagram
//
// * Class หรือ Object
//   - เขียนแทนด้วย รูปสี่เหลี่ยม
//   - ภายในกรอบมีชื่อของ object/class ในรูปแบบ {Object}:Class
//   - {Object} หมายถึง การระบุหรือไม่ระบุ object ก็ได้
//
// * เส้นแสดงลำดับเวลา
//
//     - แทนด้วย เส้นตรงประแนวตั้ง
//     - เวลาจะเดินจากด้านบนมาสู่ด้านล่าง
//     - กิจกรรมบนสุดถือเป็นกิจกรรมแรก และกิจกรรมที่อยู่ต่ำลงมาจะเป็นกิจกรรมที่เกิดขึ้นต่อจากนั้น
//
// * เส้นแสดงกิจกรรม
//
//     - แทนด้วย ลูกศรแนวนอน
//     - ชี้จาก class/object หนึ่งไปยัง class/object ตัวต่อไป
//     - ชื่อของกิจกรรมจะต้องเป็น Function ที่มีอยู่ใน
//     - class/object ที่ลูกศรชี้ไป
//     - ชื่อจะอยู่ในรูปแบบ {[Condition]}Function

// %% [markdown]
// ### 5.3.2 ประโยชน์ของ Sequence Diagram
// - ช่วยให้รู้ว่า มี Function ขาดหายไปจาก Class Diagram หรือไม่
// - ช่วยให้พิจาณาได้ว่าควรเพิ่มเติม Function ใน Class Diagram อีกหรือไม่
// - ช่วยให้สามารถปรับปรุง Class Diagram ได้สมบูรณ์ ยิ่งขึ้น

// %% [markdown]
// ### 5.3.3 รูปแบบของลูกศรใน sequence diagram
//
//
// | Type	| Description|
// |:-----:| -----------|
// |->	    |Solid line without arrow  |
// |-->	|Dotted line without arrow|
// |->>	|Solid line with arrowhead|
// |-->>	|Dotted line with arrowhead|
// |<<->>	|Solid line with bidirectional arrowheads (v11.0.0+)|
// |<<-->>	|Dotted line with bidirectional arrowheads (v11.0.0+)|
// |-x	    |Solid line with a cross at the end|
// |--x	|Dotted line with a cross at the end|
// |-)	    |Solid line with an open arrow at the end (async)|
// |--)	|Dotted line with a open arrow at the end (async)|

// %% [markdown]
// -------

// %% [markdown]
// ### 5.3.4 การวาด Sequence diagram

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// >```diff
// >sequenceDiagram
// >    Alice->>John: Hello John, how are you?
// >    John-->>Alice: Great!
// >    Alice-)John: See you later!
// >```

// %%
sequenceDiagram
   Alice->>John: Hello John, how are you?
   John-->>Alice: Great!
   Alice-)John: See you later!
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="ffc5ce23c4114044848a1208fd5a83e5"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('ffc5ce23c4114044848a1208fd5a83e5');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_ffc5ce23c4114044848a1208fd5a83e5',
//                     `sequenceDiagram
//    Alice->>John: Hello John, how are you?
//    John-->>Alice: Great!
//    Alice-)John: See you later!`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// #### ตัวอย่าง sequence diagram  ของการใช้ตู้ ATM

// %% [markdown]
// นำ code ต่อไปนี้ไปใส่ใน  mermaid code cell แล้วรันเพื่อดูผลลัพธ์
// > ```diff
// > sequenceDiagram
// >    User->>ATM: Insert card
// >    activate ATM
// >    ATM-->>User: Please input PIN
// >    deactivate ATM
// >    User->>ATM: Insert PIN
// >    activate ATM
// >    ATM-->>NetBank: Verify card and PIN
// >    activate NetBank
// >    NetBank-->>Bank: Verify account
// >    activate Bank
// >    Bank-->>NetBank: Invalid account
// >    deactivate Bank
// >    NetBank-->>ATM: Reject card
// >    deactivate NetBank
// >    ATM-->>User: Eject card
// >    deactivate ATM
// >```

// %%
sequenceDiagram User->>ATM: Insert card activate ATM ATM-->>User: Please input PIN deactivate ATM User->>ATM: Insert PIN activate ATM ATM-->>NetBank: Verify card and PIN activate NetBank NetBank-->>Bank: Verify account activate Bank Bank-->>NetBank: Invalid account deactivate Bank NetBank-->>ATM: Reject card deactivate NetBank ATM-->>User: Eject card deactivate ATM
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="41d2f7f122614b00a7babcdcaba12511"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('41d2f7f122614b00a7babcdcaba12511');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_41d2f7f122614b00a7babcdcaba12511',
//                     `sequenceDiagram User->>ATM: Insert card activate ATM ATM-->>User: Please input PIN deactivate ATM User->>ATM: Insert PIN activate ATM ATM-->>NetBank: Verify card and PIN activate NetBank NetBank-->>Bank: Verify account activate Bank Bank-->>NetBank: Invalid account deactivate Bank NetBank-->>ATM: Reject card deactivate NetBank ATM-->>User: Eject card deactivate ATM
// `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ------

// %% [markdown]
// ## แบบฝึดหัด
//
// 1. ให้ค้นหา sequence diagram จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
// 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
// 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

// %% [markdown]
// __รูปที่ 1__
//
// ![image.png](attachment:image.png)

// %%
sequenceDiagram
    participant Client
    participant Server
    participant Database

    note left of Client: Component<br/>Some text<br/>More text
    note left of Client: Component

    Client->>Server: Name 1.1 | Action
    Server->>Database: Name 1.2 | Action
    Database-->>Server: Name 1.3 | Action
    Server-->>Client: Name 1.4 | Action

    Client->>Server: Name 1.1 | Action
    Server->>Database: Name 1.2 | Action
    Database-->>Server: Name 1.3 | Action
    Server-->>Client: Name 1.4 | Action
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="8b84dde26e6f4893ab81815dafdfa655"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('8b84dde26e6f4893ab81815dafdfa655');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_8b84dde26e6f4893ab81815dafdfa655',
//                     `sequenceDiagram
//     participant Client
//     participant Server
//     participant Database
//
//     note left of Client: Component<br/>Some text<br/>More text
//     note left of Client: Component
//
//     Client->>Server: Name 1.1 | Action
//     Server->>Database: Name 1.2 | Action
//     Database-->>Server: Name 1.3 | Action
//     Server-->>Client: Name 1.4 | Action
//
//     Client->>Server: Name 1.1 | Action
//     Server->>Database: Name 1.2 | Action
//     Database-->>Server: Name 1.3 | Action
//     Server-->>Client: Name 1.4 | Action`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// __รูปที่ 2__
//
// ![image.png](attachment:image.png)

// %%
sequenceDiagram
    participant User
    participant ATM
    participant Bank

    User->>ATM: card
    ATM->>User: reqPin
    User->>ATM: enterPin
    ATM->>Bank: verify
    activate Bank
    Bank->>ATM: valid
    deactivate Bank
    ATM->>User: processing
    User->>ATM: option
    ATM->>User: withdraw
    User->>ATM: reqAmount
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="bda03f7e1eb7429aa7a1fbbb45d64dc0"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('bda03f7e1eb7429aa7a1fbbb45d64dc0');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_bda03f7e1eb7429aa7a1fbbb45d64dc0',
//                     `sequenceDiagram
//     participant User
//     participant ATM
//     participant Bank
//
//     User->>ATM: card
//     ATM->>User: reqPin
//     User->>ATM: enterPin
//     ATM->>Bank: verify
//     activate Bank
//     Bank->>ATM: valid
//     deactivate Bank
//     ATM->>User: processing
//     User->>ATM: option
//     ATM->>User: withdraw
//     User->>ATM: reqAmount`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// __รูปที่ 3__
//
// ![image.png](attachment:image.png)

// %%
sequenceDiagram
    participant Client
    participant Restaurant
    participant Delivery
    participant "Loyalty program"

    Client->>Restaurant: Order
    Restaurant-->>Client: Dinner
    Client->>Restaurant: Payment
    Client->>Restaurant: Feedback
    Restaurant-->>Client: Provide promo
    Client->>Restaurant: Order 
    Restaurant->>Delivery: Order transfer
    Delivery-->>Client: Provide delivery
    Restaurant->>Delivery: Provide delivery
    Client->>Restaurant: Order with promo
    Restaurant->>Delivery: Order transfer
    Restaurant->>"Loyalty program": Transfer of user data
    Delivery-->>Client: Provide delivery
    "Loyalty program"-->>Client: Send special offers
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="dffda5acab5a4678a1f253f26e2716ee"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('dffda5acab5a4678a1f253f26e2716ee');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_dffda5acab5a4678a1f253f26e2716ee',
//                     `sequenceDiagram
//     participant Client
//     participant Restaurant
//     participant Delivery
//     participant "Loyalty program"
//
//     Client->>Restaurant: Order
//     Restaurant-->>Client: Dinner
//     Client->>Restaurant: Payment
//     Client->>Restaurant: Feedback
//     Restaurant-->>Client: Provide promo
//     Client->>Restaurant: Order
//     Restaurant->>Delivery: Order transfer
//     Delivery-->>Client: Provide delivery
//     Restaurant->>Delivery: Provide delivery
//     Client->>Restaurant: Order with promo
//     Restaurant->>Delivery: Order transfer
//     Restaurant->>"Loyalty program": Transfer of user data
//     Delivery-->>Client: Provide delivery
//     "Loyalty program"-->>Client: Send special offers`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// </script>
// </div>

// %% [markdown]
// ![image.png](attachment:image.png)
