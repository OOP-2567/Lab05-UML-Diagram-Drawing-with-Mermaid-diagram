# %% [markdown]
# ## แบบฝึดหัด
#
# 1. ให้ค้นหา flowchart จาก internet มา 3 ภาพ ที่วาดขึ้นโดยโปรแกรมอื่นที่ไม่ใช่ mermaid  โดยมีองค์ประกอบในไดอะแกรมไม่น้อยกว่า 5 ชิ้นส่วน
# 2. เขียน code ในภาษา mermaid diagram เพื่อวาดตามไดอะแกรมนั้น
# 3. นำภาพที่ได้เทียบกับต้นฉบับ โดย capture เป็น png แล้วแนบลิ้งค์มาในไฟล์ ipynb นี้ (อย่าวางภาพลงไปโดยการ copy & paste เนื่องจากจะทำให้ไฟล์ ipynb มีขนาดที่โตเกินไป)

# %%
# %% Example 1. Flow chart
# flowchart TD
#     A[เริ่มต้น] --> B{ปฏิบัติงาน};
#     B --> C(ปฏิบัติงาน);
#     C --> D{การตัดสินใจ};
#     D -- ใช่ --> E[สิ้นสุด];
#     D -- ไม่ใช่ --> B;

# %% [markdown]
# 1.![image.png](attachment:image.png)

# %%
# %% Example 2. Flow chart
# flowchart TD
#     A[เริ่มต้น] --> B{อ่านค่าข้อมูลเข้า<br>มาเก็บไว้ในตัวแปร<br>A และ B};
#     B --> C{A > B?};
#     C -- ใช่ --> D{คำนวณ<br>RESULT = A + B};
#     C -- ไม่ใช่ --> E{คำนวณ<br>RESULT = A - B};
#     D --> F(( ));
#     E --> F;
#     F --> G[จบงาน];

# %% [markdown]
# 2.![image.png](attachment:image.png)

# %%
# %% Example 3. Flow chart
# flowchart LR
#     A[Start] --> B{Are you happy?};
#     B -- Yes --> C{Very good,<br>have a great<br>day!};
#     C --> D[Bliss!];
#     B -- No --> E{Want<br>to be<br>happy?};
#     E -- Yes --> F{Very good,<br>then you are<br>already happy};
#     F --> D;
#     E -- No --> G{Gosh! Start all<br>over again!};
#     G --> A;

# %% [markdown]
# 3.![image.png](attachment:image.png)
